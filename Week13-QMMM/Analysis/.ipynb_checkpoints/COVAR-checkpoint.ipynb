# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_covar = pd.read_csv("../Outputs/monitor/MONITOR-COLVAR.metadynLog",header=None,sep="\s+",usecols=[0,1],names=['Time[ps]','Reaction Coordinate'])
df_covar
# Out:
#       Time[ps]  Reaction Coordinate
# 0          0.0              4.06421
# 1          5.0              4.18805
# 2         10.0              4.25207
# 3         15.0              4.22732
# 4         20.0              4.15487
# ...        ...                  ...
# 1185    4980.0              4.24953
# 1186    4985.0              4.11134
# 1187    4990.0              4.05926
# 1188    4995.0              4.11140
# 1189    5000.0              4.24575
#
# [1190 rows x 2 columns]

# %%
sns.lineplot(data=df_covar, x = 'Time[ps]', y = 'Reaction Coordinate')
plt.show()
# Out:
# /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# for metaD
df_covar_metaD = pd.read_csv("../Outputs/metad1_initmonitor/METADYN-COLVAR.metadynLog",header=None,sep="\s+",usecols=[0,1],names=['Time[ps]','Reaction Coordinate'])
df_covar_metaD
# Out:
#       Time[ps]  Reaction Coordinate
# 0          0.0              4.24575
# 1          5.0              4.25093
# 2         10.0              4.11552
# 3         15.0              4.02769
# 4         20.0              4.06618
# ...        ...                  ...
# 6033   29980.0              2.88697
# 6034   29985.0              2.98135
# 6035   29990.0              3.08340
# 6036   29995.0              3.13505
# 6037   30000.0              3.12887
#
# [6038 rows x 2 columns]

# %%
sns.lineplot(data=df_covar_metaD, x = 'Time[ps]', y = 'Reaction Coordinate')
plt.show()
# Out:
# /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /share/apps/anaconda3/2024.02/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
hill_height_freq = 0.05  # Extracted from .inp
hill_width_freq = 0.2    # Extracted from .inp
hill_frequency_freq = 50 # Extracted from .inp

plt.plot(df_monitor_freq["Time"], df_monitor_freq["CV"], label=f"Modified Hill Parameters\nHill: h={hill_height_freq}, w={hill_width_freq}, f={hill_frequency_freq}")

# %%
# for metaD



df_covar_metaD = pd.read_csv("../Outputs/metad1_initmonitor/METADYN-COLVAR.metadynLog",header=None,sep="\s+",usecols=[0,1],names=['Time[ps]','Reaction Coordinate'])
df_covar_metaD
